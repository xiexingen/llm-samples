# %% [markdown]
# 1. DeepSeek  结合提示词模板

# %%
# 通过 langchain 的 core 库引入基础的提示词模板
from langchain_core.prompts import PromptTemplate
# 引入 deepseek 的 sdk
from langchain_deepseek import ChatDeepSeek
from rich import print

# 初始化 deepseek 的 sdk 创建 deepseek 模型的实例
llm = ChatDeepSeek(model="deepseek-chat")

# 创建一个问题模板，其中 {Query} 是占位符,表示客户的查询
# 系统提示词
# 用户提示词 占位符 {Query}
template = """
你作为一名经验丰富的客服代表，请为以下客服问题提供解答:
{Query}
"""

prompt = PromptTemplate(
  template=template, # 定义问题模板
  input_variables=["Query"] # 定义占位符
)

# 这里是实际的用户输入，例如: "如何安装"
# 用户提示词+系统提示词 =最终提示词
final_prompt = prompt.format(Query="如何安装")

print(f"组合后的用户请求:{final_prompt}")

# 调用 deepseek 模型进行回答
response = llm(final_prompt)
print(response)
# Out:
# 组合后的用户请求:
# 你作为一名经验丰富的客服代表，请为以下客服问题提供解答:
# 如何安装
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7276\724437236.py:30: LangChainDeprecationWarning: The method `BaseChatModel.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   response = llm(final_prompt)
# AIMessage(
#     content='您好！感谢您的提问。关于“如何安装”的问题，由于您没有提供具体的产品或软件名称，我将为您提供一些通用的安
# 装步骤。如果您能提供更多详细信息，我可以为您提供更具体的指导。\n\n### 通用安装步骤：\n1. **下载安装文件**：\n   -
# 访问官方网站或授权渠道，下载最新的安装文件。\n   -
# 确保下载的文件与您的操作系统（如Windows、macOS、Linux等）兼容。\n\n2. **运行安装程序**：\n   -
# 找到下载的安装文件（通常是一个 `.exe`、`.dmg` 或 `.pkg` 文件）。\n   - 双击运行安装程序。\n\n3.
# **同意许可协议**：\n   - 阅读并同意软件许可协议（如果有）。\n\n4. **选择安装位置**：\n   -
# 默认情况下，软件会安装到系统推荐的目录。如果需要，您可以自定义安装路径。\n\n5. **完成安装**：\n   -
# 点击“安装”按钮，等待安装完成。\n   - 安装完成后，您可能会看到“完成”或“启动程序”的选项。\n\n6. **启动软件**：\n   -
# 安装完成后，您可以通过桌面快捷方式、开始菜单或应用程序文件夹启动软件。\n\n### 注意事项：\n-
# **系统要求**：确保您的设备满足软件的最低系统要求（如操作系统版本、内存、硬盘空间等）。\n-
# **权限问题**：在安装过程中，可能需要管理员权限。请确保您有足够的权限来完成安装。\n-
# **网络连接**：某些软件在安装过程中需要联网下载额外组件，请确保网络连接稳定。\n\n如果您遇到任何问题，请提供更多详细
# 信息（如软件名称、操作系统版本、错误提示等），我将为您提供进一步的帮助！ 😊',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 357,
#             'prompt_tokens': 22,
#             'total_tokens': 379,
#             'completion_tokens_details': None,
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0},
#             'prompt_cache_hit_tokens': 0,
#             'prompt_cache_miss_tokens': 22
#         },
#         'model_name': 'deepseek-chat',
#         'system_fingerprint': 'fp_3a5770e1b4',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='run-566f979b-5688-4982-b14c-9232e945273a-0',
#     usage_metadata={
#         'input_tokens': 22,
#         'output_tokens': 357,
#         'total_tokens': 379,
#         'input_token_details': {'cache_read': 0},
#         'output_token_details': {}
#     }
# )

# %% [markdown]
# 2. DeepSeek 通过 Role 实现精准回应
#
# LangChain 提供了不同类型的 MessagePromptTemplate
#
# HumanMessagePromptTemplate: 人类消息
#
# SystemMessagePromptTemplate: 系统消息(Instruction、Conexti)
#
# AIMessagePromptTemplate: AI 消息
#
# 可以使用 ChatMessagePromptTemplate 它允许用户指定角色名称

# %%
# 导入 ChatMessagePromptTemplate 类，用于创建聊天消息模板
from langchain_core.prompts import ChatMessagePromptTemplate
# 引入 deepseek 的 sdk
from langchain_deepseek import ChatDeepSeek

llm = ChatDeepSeek(model="deepseek-chat")

template = """
你是一名经验丰富的客服代表，请为以下客服问题提供解答:
{Query}
"""

# 创建一个聊天消息提示模板对象，指定角色为 "技术支持"
chat_message_prompt = ChatMessagePromptTemplate.from_template(template=template,role="技术支持")

# 格式化提示模板，将用户的实际查询填充到占位符 {Query} 中
formatted_prompt = chat_message_prompt.format(Query="如何安装到本地?")

# 将格式化的提示转换成字符串，以便传递给大模型
prompts = str(formatted_prompt)

response = llm(prompts)
print(response)
# Out:
# AIMessage(
#     content='您好！感谢您联系技术支持。关于如何将软件安装到本地，以下是一般的安装步骤，具体步骤可能会因软件的不同而
# 有所差异：\n\n### 1. **下载安装包**\n   -
# 首先，请访问软件的官方网站或授权下载渠道，找到适合您操作系统的安装包（如Windows、macOS、Linux等）。\n   -
# 点击下载按钮，将安装包保存到您的电脑上。\n\n### 2. **运行安装程序**\n   -
# 找到您下载的安装包（通常位于“下载”文件夹中）。\n   - 双击安装包以启动安装程序。\n\n### 3. **遵循安装向导**\n   -
# 安装程序通常会弹出一个安装向导，引导您完成安装过程。\n   -
# 请仔细阅读每一步的提示信息，并根据您的需求选择安装选项（如安装路径、语言设置等）。\n\n### 4. **同意许可协议**\n   -
# 在安装过程中，您可能会被要求阅读并同意软件的许可协议。请仔细阅读协议内容，如果同意，请勾选“我接受许可协议”或类似选
# 项。\n\n### 5. **选择安装位置**\n   -
# 安装程序通常会提示您选择软件的安装位置。您可以选择默认路径，也可以点击“浏览”按钮选择其他文件夹。\n\n### 6.
# **完成安装**\n   - 点击“安装”或“下一步”按钮，安装程序将开始将软件安装到您的电脑上。\n   -
# 安装完成后，您可能会看到“安装成功”或“完成”的提示。此时，您可以点击“完成”或“关闭”按钮退出安装程序。\n\n### 7.
# **启动软件**\n   - 安装完成后，您可以在桌面或开始菜单中找到软件的快捷方式，双击即可启动软件。\n\n### 8.
# **激活或注册（如需要）**\n   -
# 某些软件可能需要激活或注册才能使用。请根据软件的提示输入您的激活码或注册信息。\n\n如果您在安装过程中遇到任何问题，
# 或者需要进一步的帮助，请随时联系我们的技术支持团队。我们将竭诚为您服务！\n\n祝您安装顺利！\n\n**技术支持团队**',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 434,
#             'prompt_tokens': 45,
#             'total_tokens': 479,
#             'completion_tokens_details': None,
#             'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0},
#             'prompt_cache_hit_tokens': 0,
#             'prompt_cache_miss_tokens': 45
#         },
#         'model_name': 'deepseek-chat',
#         'system_fingerprint': 'fp_3a5770e1b4',
#         'finish_reason': 'stop',
#         'logprobs': None
#     },
#     id='run-29be03ba-fb8a-460c-9f1a-fa5480004f65-0',
#     usage_metadata={
#         'input_tokens': 45,
#         'output_tokens': 434,
#         'total_tokens': 479,
#         'input_token_details': {'cache_read': 0},
#         'output_token_details': {}
#     }
# )
